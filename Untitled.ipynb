# %%
# %run pacman.py
# Out:
# Pacman died! Score: 207
# Average Score: 207.0
# Scores:        207.0
# Win Rate:      0/1 (0.00)
# Record:        Loss

# %%
# %run pacman.py -p ReflexAgent
# Out:
# (8, 1)
# FFFFFFFFFFFFFFFFFFFF
# FFTTTFTTTTTTTTFTTTTF
# FTFFTFTFFFFFFTFTFFTF
# FTFTTTTTTTTTTTTTTFTF
# FTFTFFTFFFFFFTFFTFTF
# FTTTTTTFFFFFFTTTTTTF
# FTFTFFTFFFFFFTFFTFTF
# FTFTTTTTTTTTTTTTTFTF
# FTFFTFTFFFFFFTFTFFTF
# FTTTTFTTFFTTTTFTTTFF
# FFFFFFFFFFFFFFFFFFFF
# (8, 5)
# (11, 5)
# [0, 0]
# (9, 1)
# FFFFFFFFFFFFFFFFFFFF
# FFTTTFTTTTTTTTFTTTTF
# FTFFTFTFFFFFFTFTFFTF
# FTFTTTTTTTTTTTTTTFTF
# FTFTFFTFFFFFFTFFTFTF
# FTTTTTTFFFFFFTTTTTTF
# FTFTFFTFFFFFFTFFTFTF
# FTFTTTTTTTTTTTTTTFTF
# FTFFTFTFFFFFFTFTFFTF
# FTTTTFTTTFTTTTFTTTFF
# FFFFFFFFFFFFFFFFFFFF
# (8, 5)
# (11, 5)
# [0, 0]
# (10, 1)
# FFFFFFFFFFFFFFFFFFFF
# FFTTTFTTTTTTTTFTTTTF
# FTFFTFTFFFFFFTFTFFTF
# FTFTTTTTTTTTTTTTTFTF
# FTFTFFTFFFFFFTFFTFTF
# FTTTTTTFFFFFFTTTTTTF
# FTFTFFTFFFFFFTFFTFTF
# FTFTTTTTTTTTTTTTTFTF
# FTFFTFTFFFFFFTFTFFTF
# FTTTTFTTTFFTTTFTTTFF
# FFFFFFFFFFFFFFFFFFFF
# (8, 5)
# (11, 5)
# [0, 0]
# (9, 1)
# FFFFFFFFFFFFFFFFFFFF
# FFTTTFTTTTTTTTFTTTTF
# FTFFTFTFFFFFFTFTFFTF
# FTFTTTTTTTTTTTTTTFTF
# FTFTFFTFFFFFFTFFTFTF
# ...

# %%
# %run autograder.py -q q5
# Out:
# Starting on 6-8 at 14:04:26
#
# Question q5
# ...
#
# Pacman emerges victorious! Score: 1077
# Pacman emerges victorious! Score: 1219
# Pacman emerges victorious! Score: 1217
# Pacman emerges victorious! Score: 916
# Pacman emerges victorious! Score: 978
# Pacman emerges victorious! Score: 730
# Pacman emerges victorious! Score: 1199
# Pacman emerges victorious! Score: 1100
# Pacman emerges victorious! Score: 770
# Pacman emerges victorious! Score: 1200
# Average Score: 1040.6
# Scores:        1077.0, 1219.0, 1217.0, 916.0, 978.0, 730.0, 1199.0, 1100.0, 770.0, 1200.0
# Win Rate:      10/10 (1.00)
# Record:        Win, Win, Win, Win, Win, Win, Win, Win, Win, Win
# *** PASS: test_cases\q5\grade-agent.test (6 of 6 points)
# ***     1040.6 average score (2 of 2 points)
# ***         Grading scheme:
# ***          < 500:  0 points
# ***         >= 500:  1 points
# ***         >= 1000:  2 points
# ***     10 games not timed out (1 of 1 points)
# ***         Grading scheme:
# ...

# %%
# %run pacman.py -p MinimaxAgent -l trappedClassic -a depth=3
# Out:
# Pacman died! Score: -501
# Average Score: -501.0
# Scores:        -501.0
# Win Rate:      0/1 (0.00)
# Record:        Loss

# %%
# %run pacman.py -p AlphaBetaAgent -l trappedClassic -a depth=3 -q -n 10
# Out:
# Pacman died! Score: -501
# Pacman died! Score: -501
# Pacman died! Score: -501
# Pacman died! Score: -501
# Pacman died! Score: -501
# Pacman died! Score: -501
# Pacman died! Score: -501
# Pacman died! Score: -501
# Pacman died! Score: -501
# Pacman died! Score: -501
# Average Score: -501.0
# Scores:        -501.0, -501.0, -501.0, -501.0, -501.0, -501.0, -501.0, -501.0, -501.0, -501.0
# Win Rate:      0/10 (0.00)
# Record:        Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss, Loss

# %%
# %run pacman.py -p AlphaBetaAgent -a depth=3 -l smallClassic
# Out:
# Pacman died! Score: -392
# Average Score: -392.0
# Scores:        -392.0
# Win Rate:      0/1 (0.00)
# Record:        Loss
